# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidP0011/apps_functions/blob/main/app_pdf_utils.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INICIALIZACIÓN

# %%
def install_dpm_repos(config: dict) -> None:
    """
    Instala repositorios DPM y lista las funciones de cada paquete instalado.

    El diccionario de configuración debe tener la clave:
        - github_repo_url_list: Lista de URLs de repositorios GitHub
          Ejemplo:
            {
                "github_repo_url_list": [
                  "https://github.com/DavidP0011/common_functions",
                  "https://github.com/DavidP0011/utils_functions",
                  "https://github.com/DavidP0011/etl_functions"
                  ]
            }

    La función procede en dos pasos para cada repositorio:
      1. Se instala de manera “normal” (pip install --upgrade --no-cache-dir git+<repo_url>)
         para instalar las dependencias si faltan.
      2. Se fuerza la reinstalación de los archivos .py con --force-reinstall y --no-deps
         (pip install --upgrade --force-reinstall --no-deps --no-cache-dir git+<repo_url>).

    Luego, se detecta dinámicamente el nombre del paquete instalado y se recorre
    cada paquete para imprimir las funciones definidas.
    """
    import subprocess
    import sys
    import importlib
    import pkgutil
    import inspect

    # Para detectar distribuciones y top-level packages
    try:
        import importlib.metadata as metadata
    except ImportError:
        # Si la versión de Python es muy antigua:
        import importlib_metadata as metadata

    def _validate_config(cfg: dict) -> list:
        """Valida que la configuración tenga la clave 'github_repo_url_list' con una lista."""
        if "github_repo_url_list" not in cfg:
            raise ValueError("[VALIDATION [ERROR ❌]] La configuración debe contener la clave 'github_repo_url_list'.")
        if not isinstance(cfg["github_repo_url_list"], list):
            raise ValueError("[VALIDATION [ERROR ❌]] La clave 'github_repo_url_list' debe ser una lista de URLs.")
        return cfg["github_repo_url_list"]

    def _install_repo(repo_url: str) -> None:
        """
        Instala un repositorio en dos pasos:
          1. Instala el repositorio de forma normal (para que se instalen las dependencias si aún no están).
          2. Fuerza la reinstalación del código (los archivos .py) sin tocar las dependencias (--no-deps).
        """
        print(f"\n[START ▶️] Instalación inicial (con dependencias) del repositorio: {repo_url}", flush=True)
        cmd_normal = [
            sys.executable, "-m", "pip", "install", "-q",
            "--upgrade", "--no-cache-dir",
            f"git+{repo_url}"
        ]
        try:
            subprocess.check_call(cmd_normal)
            print(f"[SUCCESS ✅] Instalación inicial completada.", flush=True)
        except subprocess.CalledProcessError as e:
            print(f"[ERROR ❌] Falló la instalación inicial del repositorio. Detalle: {e}", flush=True)

        print(f"\n[START ▶️] Forzando reinstalación del código del repositorio: {repo_url}", flush=True)
        cmd_force = [
            sys.executable, "-m", "pip", "install", "-q",
            "--upgrade", "--force-reinstall", "--no-deps", "--no-cache-dir",
            f"git+{repo_url}"
        ]
        try:
            subprocess.check_call(cmd_force)
            print(f"[SUCCESS ✅] Reinstalación del código completada.", flush=True)
        except subprocess.CalledProcessError as e:
            print(f"[ERROR ❌] Falló la reinstalación del código. Detalle: {e}", flush=True)

    def _detect_installed_package_name(before_set: set, repo_url: str) -> str:
        """
        Compara las distribuciones antes y después de la instalación:
        - before_set: conjunto de nombres de distribución (metadata["Name"]) previos.
        - repo_url: URL del repositorio (para intentar emparejar por substring).
        Devuelve el nombre de paquete (top-level) para importar.
        """
        # Obtenemos el conjunto actual de distribuciones instaladas
        after_set = {dist.metadata["Name"] for dist in metadata.distributions()}

        # Identificamos cuáles son las nuevas distribuciones
        nuevas = list(after_set - before_set)

        repo_name = repo_url.rstrip("/").split("/")[-1].lower()

        if not nuevas:
            # Si no hay distribuciones nuevas, intentamos emparejar alguna existente por substring
            candidatos = [dist.metadata["Name"] for dist in metadata.distributions() if repo_name in dist.metadata["Name"].lower()]
            if candidatos:
                elegida_dist = candidatos[0]
                print(f"[INFO ℹ️] No se detectó distribución nueva. Se asume '{elegida_dist}' para '{repo_name}'.", flush=True)
            else:
                print(f"[WARN ⚠️] No se detectó nueva distribución ni coincidencias para '{repo_name}'. Se usará '{repo_name}' por defecto.", flush=True)
                return repo_name
        else:
            # Si hay más de una nueva, intentamos filtrar por substring
            if len(nuevas) > 1:
                filtradas = [d for d in nuevas if repo_name in d.lower()]
                elegida_dist = filtradas[0] if filtradas else nuevas[0]
                print(f"[INFO ℹ️] Se detectaron múltiples distribuciones nuevas {nuevas}. Se elige '{elegida_dist}'.", flush=True)
            else:
                elegida_dist = nuevas[0]
            print(f"[INFO ℹ️] Se detectó la nueva distribución '{elegida_dist}'.", flush=True)

        # Ahora obtenemos el top-level package desde la metadata
        try:
            dist_info = metadata.distribution(elegida_dist)
            top_level_txt = dist_info.read_text("top_level.txt")
            if top_level_txt:
                top_levels = [line.strip() for line in top_level_txt.splitlines() if line.strip()]
                paquete = top_levels[0] if top_levels else elegida_dist
                print(f"[INFO ℹ️] Para la distribución '{elegida_dist}', se detectó el paquete top-level: '{paquete}'", flush=True)
                return paquete
            else:
                print(f"[WARN ⚠️] 'top_level.txt' vacío para '{elegida_dist}'. Se usará '{elegida_dist}' como paquete.", flush=True)
                return elegida_dist
        except Exception as e:
            # Si no existe top_level.txt o falla, devolvemos el nombre de la distribución
            print(f"[ERROR ❌] No se pudo leer 'top_level.txt' de '{elegida_dist}': {e}. Usando '{elegida_dist}'.", flush=True)
            return elegida_dist

    def _list_functions(package) -> None:
        """
        Recorre todos los módulos y submódulos del paquete e imprime las funciones definidas en cada uno.
        """
        print(f"\n[START ▶️] Funciones en el paquete: {package.__name__}", flush=True)
        for finder, module_name, is_pkg in pkgutil.walk_packages(package.__path__, package.__name__ + "."):
            try:
                modulo = importlib.import_module(module_name)
                funciones = [
                    nombre for nombre, objeto in inspect.getmembers(modulo, inspect.isfunction)
                    if inspect.getmodule(objeto) == modulo
                ]
                print(f"\n Módulo: {module_name}", flush=True)
                if funciones:
                    for funcion in funciones:
                        print("  -", funcion, flush=True)
                else:
                    print("  (No se encontraron funciones definidas)", flush=True)
            except Exception as e:
                print(f"[ERROR ❌] Falló al importar el módulo {module_name}: {e}", flush=True)

    # Mensaje de inicio del proceso global
    print("🔹🔹🔹 Instalación de Repositorios DPM y listado de funciones 🔹🔹🔹", flush=True)

    # Validación de la configuración
    github_repo_url_list = _validate_config(config)

    for repo_url in github_repo_url_list:
        # Tomamos snapshot de distribuciones antes de instalar
        antes = {dist.metadata["Name"] for dist in metadata.distributions()}

        # Instalamos el repositorio en dos pasos
        _install_repo(repo_url)

        # Detectamos automáticamente el nombre del paquete instalado
        package_name = _detect_installed_package_name(antes, repo_url)

        # Importamos el paquete y listamos sus funciones
        try:
            print(f"\n\n🔹🔹🔹 Importando el paquete: {package_name} 🔹🔹🔹", flush=True)
            if package_name in sys.modules:
                del sys.modules[package_name]
            importlib.invalidate_caches()
            paquete = importlib.import_module(package_name)
            _list_functions(paquete)
        except Exception as e:
            print(f"❌ [ERROR] Falló al importar el paquete '{package_name}': {e}", flush=True)

    print("\n\n🔹🔹🔹 [FINISHED ✅] Proceso completado. 🔹🔹🔹", flush=True)

# %%
# @title GIBHUB INSTALL DPM FUNCTIONS
config = {
    "github_repo_url_list": [
        # "https://github.com/DavidP0011/common_functions",
        "https://github.com/DavidP0011/utils_functions",
        # "https://github.com/DavidP0011/etl_functions",
        "https://github.com/DavidP0011/apps_functions"
    ]
}


install_dpm_repos(config)
# Out:
# 🔹🔹🔹 Instalación de Repositorios DPM y listado de funciones 🔹🔹🔹
#
# [START ▶️] Instalación inicial (con dependencias) del repositorio: https://github.com/DavidP0011/common_functions
# [SUCCESS ✅] Instalación inicial completada.
#
# [START ▶️] Forzando reinstalación del código del repositorio: https://github.com/DavidP0011/common_functions
# [SUCCESS ✅] Reinstalación del código completada.
# [INFO ℹ️] No se detectó distribución nueva. Se asume 'dpm_common_functions' para 'common_functions'.
# [INFO ℹ️] Para la distribución 'dpm_common_functions', se detectó el paquete top-level: 'dpm_common_functions'
#
#
# 🔹🔹🔹 Importando el paquete: dpm_common_functions 🔹🔹🔹
#
# [START ▶️] Funciones en el paquete: dpm_common_functions
#
#  Módulo: dpm_common_functions.dpm_GCP_ini_utils
#   - _ini_authenticate_API
#   - ini_environment_identification
#   - ini_google_drive_instalation
#
# [START ▶️] Instalación inicial (con dependencias) del repositorio: https://github.com/DavidP0011/utils_functions
# [SUCCESS ✅] Instalación inicial completada.
#
# [START ▶️] Forzando reinstalación del código del repositorio: https://github.com/DavidP0011/utils_functions
# [SUCCESS ✅] Reinstalación del código completada.
# [INFO ℹ️] No se detectó distribución nueva. Se asume 'dpm_utils_functions' para 'utils_functions'.
# [INFO ℹ️] Para la distribución 'dpm_utils_functions', se detectó el paquete top-level: 'dpm_utils_functions'
#
#
# 🔹🔹🔹 Importando el paquete: dpm_utils_functions 🔹🔹🔹
#
# [START ▶️] Funciones en el paquete: dpm_utils_functions
#
#  Módulo: dpm_utils_functions.dpm_old
#   - ini_install_libraries
#   - ini_load_dpm_libs
#
#  Módulo: dpm_utils_functions.dpm_pdf_utils
#   - pdf_merge_intercalated_pages_file
#
#  Módulo: dpm_utils_functions.dpm_tables
#   - DType_df_to_df
#   - fields_name_format
#   - table_DF_to_various_targets
#   - table_various_sources_to_DF
#   - tables_consolidate_duplicates_df
#
# [START ▶️] Instalación inicial (con dependencias) del repositorio: https://github.com/DavidP0011/apps_functions
# [SUCCESS ✅] Instalación inicial completada.
#
# [START ▶️] Forzando reinstalación del código del repositorio: https://github.com/DavidP0011/apps_functions
# [SUCCESS ✅] Reinstalación del código completada.
# [INFO ℹ️] No se detectó distribución nueva. Se asume 'dpm_apps_functions' para 'apps_functions'.
# [INFO ℹ️] Para la distribución 'dpm_apps_functions', se detectó el paquete top-level: 'dpm_apps_functions'
#
#
# 🔹🔹🔹 Importando el paquete: dpm_apps_functions 🔹🔹🔹
#
# [START ▶️] Funciones en el paquete: dpm_apps_functions
#
#  Módulo: dpm_apps_functions.dpm_apps_utils
#   - LLM_process_text
#   - df_to_whisper_transcribe_to_spreadsheet
#   - files_path_collect_df
#
#
# 🔹🔹🔹 [FINISHED ✅] Proceso completado. 🔹🔹🔹

# %%
# @title IDENTIFICACION DE ENTORNO, INSTALACIÓN GOOGLE DRIVE

from dpm_common_functions.dpm_GCP_ini_utils import ini_environment_identification, ini_google_drive_instalation

# Detectar el entorno de ejecución
ini_environment_identificated = ini_environment_identification()
print(f"[INFO ℹ️] Entorno detectado: {ini_environment_identificated}", flush=True)

GCP_json_keyfile_local = r"D:\PYTHON\proyectos\api_keys\animum-dev-apps-venv-python-local.json"
GCP_json_keyfile_colab = "/content/drive/MyDrive/ANIMUM DIRECCION/DIRECCION BI/NOTEBOOKS/api_keys/animum-dev-datawarehouse-google-colab.json"
GCP_json_keyfile_GCP_secret_id = "notebook-vm"

# Montar Google Drive si entorno_identificado_str es Colab
params = {"entorno_identificado_str": ini_environment_identificated}
ini_google_drive_instalation(params)
# Out:
# [INFO ℹ️] Entorno detectado: LOCAL
# [INFO ℹ️] El entorno 'LOCAL' no requiere montaje de Google Drive.

# %%
# @title IMPORTACIÓN DE LIBRERÍAS WHISPER Y FFMPEG

# Verificar e instalar el paquete 'whisper'
try:
    import whisper
except ImportError:
    print("El paquete 'whisper' no está instalado. Procediendo con la instalación...")
    # !pip install git+https://github.com/openai/whisper.git
    import whisper

# Verificar e instalar el paquete 'ffmpeg-python'
try:
    import ffmpeg
except ImportError:
    print("El paquete 'ffmpeg-python' no está instalado. Procediendo con la instalación...")
    # !pip install ffmpeg-python

# Instalar y verificar 'ffmpeg' a nivel del sistema
import os
if os.system("ffmpeg -version") != 0:
    print("FFmpeg no está instalado. Procediendo con la instalación...")
    # !apt-get update
    # !apt-get install -y ffmpeg
    # !ffmpeg -version
else:
    print("FFmpeg ya está instalado.")
# Out:
# FFmpeg ya está instalado.

# %% [markdown]
# # EJECUCIONES

# %%
# @title RECOPILACIÓN DE RUTAS DE VIDEO

# Ejemplo de configuración
config = {
    "video_files_root_path": r"\\animum.local\Produccion\LOL-Contenido\ASIGNATURAS",
    "video_files_target_search_folder": ["CAPITULOS EXPORTAR","CAPITULO EXPORTAR"],
    "video_files_target_search_extension": [".mp4"],

    "ini_environment_identificated": ini_environment_identificated,
    "json_keyfile_local": GCP_json_keyfile_local,
    "json_keyfile_colab": GCP_json_keyfile_colab,
    "json_keyfile_GCP_secret_id": GCP_json_keyfile_GCP_secret_id,
}

# Ejecución de la función con manejo de errores interno
from dpm_apps_functions.dpm_apps_utils import files_path_collect_df
df_videos = files_path_collect_df(config)
df_videos
# Out:
# [PROCESS START ▶️] Iniciando la recolección de archivos.
# [VALIDATION SUCCESS ✅] Parámetros validados correctamente.
# [FILE SEARCH START ▶️] Buscando archivos en '\\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA' con extensiones: ['.mp4'].
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Como funciona el curso - 010 Como funciona el curso.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T000 COMO FUNCIONA EL CURSO\L010 COMO FUNCIONA EL CURSO\CAPITULOS EXPORTAR\010 Como funciona el curso - 010 Como funciona el curso.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Teoria del color - 010 Que es el color.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T010 NOCIONES SOBRE EL COLOR\L010 TEORIA DEL COLOR\CAPITULOS EXPORTAR\010 Teoria del color - 010 Que es el color.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Teoria del color - 020 El color tecnico.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T010 NOCIONES SOBRE EL COLOR\L010 TEORIA DEL COLOR\CAPITULOS EXPORTAR\010 Teoria del color - 020 El color tecnico.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Teoria del color - 030 Percepcion del color.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T010 NOCIONES SOBRE EL COLOR\L010 TEORIA DEL COLOR\CAPITULOS EXPORTAR\010 Teoria del color - 030 Percepcion del color.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Teoria del color - 040 Colores primarios y secundarios 1.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T010 NOCIONES SOBRE EL COLOR\L010 TEORIA DEL COLOR\CAPITULOS EXPORTAR\010 Teoria del color - 040 Colores primarios y secundarios 1.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Teoria del color - 050 El circulo cromatico.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T010 NOCIONES SOBRE EL COLOR\L010 TEORIA DEL COLOR\CAPITULOS EXPORTAR\010 Teoria del color - 050 El circulo cromatico.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Teoria del color - 060 Analisis de la imagen.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T010 NOCIONES SOBRE EL COLOR\L010 TEORIA DEL COLOR\CAPITULOS EXPORTAR\010 Teoria del color - 060 Analisis de la imagen.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Teoria del color - 070 El color artistico.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T010 NOCIONES SOBRE EL COLOR\L010 TEORIA DEL COLOR\CAPITULOS EXPORTAR\010 Teoria del color - 070 El color artistico.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Teoria del color - 080 Tono, saturacion y brillo.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T010 NOCIONES SOBRE EL COLOR\L010 TEORIA DEL COLOR\CAPITULOS EXPORTAR\010 Teoria del color - 080 Tono, saturacion y brillo.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Teoria del color - 090 Balance de color basado en la composicion.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T010 NOCIONES SOBRE EL COLOR\L010 TEORIA DEL COLOR\CAPITULOS EXPORTAR\010 Teoria del color - 090 Balance de color basado en la composicion.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Teoria del color - 100 Temperatura del color.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T010 NOCIONES SOBRE EL COLOR\L010 TEORIA DEL COLOR\CAPITULOS EXPORTAR\010 Teoria del color - 100 Temperatura del color.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Teoria del color - 110 Esquemas de color.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T010 NOCIONES SOBRE EL COLOR\L010 TEORIA DEL COLOR\CAPITULOS EXPORTAR\010 Teoria del color - 110 Esquemas de color.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Teoria del color - 120 Constancia de color.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T010 NOCIONES SOBRE EL COLOR\L010 TEORIA DEL COLOR\CAPITULOS EXPORTAR\010 Teoria del color - 120 Constancia de color.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Teoria del color - 130 Adaptacion y contraste de color.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T010 NOCIONES SOBRE EL COLOR\L010 TEORIA DEL COLOR\CAPITULOS EXPORTAR\010 Teoria del color - 130 Adaptacion y contraste de color.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Psicologia del color - 010 Objetivos del colorista.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T010 NOCIONES SOBRE EL COLOR\L020 PSICOLOGIA DEL COLOR\CAPITULOS EXPORTAR\020 Psicologia del color - 010 Objetivos del colorista.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Psicologia del color - 020 El color en la comunicación.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T010 NOCIONES SOBRE EL COLOR\L020 PSICOLOGIA DEL COLOR\CAPITULOS EXPORTAR\020 Psicologia del color - 020 El color en la comunicación.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Psicologia del color - 030 El color en el storytelling.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T010 NOCIONES SOBRE EL COLOR\L020 PSICOLOGIA DEL COLOR\CAPITULOS EXPORTAR\020 Psicologia del color - 030 El color en el storytelling.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Psicologia del color - 040 Sensaciones que transmite el color.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T010 NOCIONES SOBRE EL COLOR\L020 PSICOLOGIA DEL COLOR\CAPITULOS EXPORTAR\020 Psicologia del color - 040 Sensaciones que transmite el color.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Psicologia del color - 050 Armonias de color.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T010 NOCIONES SOBRE EL COLOR\L020 PSICOLOGIA DEL COLOR\CAPITULOS EXPORTAR\020 Psicologia del color - 050 Armonias de color.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Psicologia del color - 060 Memoria del color.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T010 NOCIONES SOBRE EL COLOR\L020 PSICOLOGIA DEL COLOR\CAPITULOS EXPORTAR\020 Psicologia del color - 060 Memoria del color.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Definiciones - 010 Color correction vs color grading.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T020 CONCEPTOS\L010 DEFINICIONES\CAPITULOS EXPORTAR\010 Definiciones - 010 Color correction vs color grading.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Definiciones - 020 Color grading workflow.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T020 CONCEPTOS\L010 DEFINICIONES\CAPITULOS EXPORTAR\010 Definiciones - 020 Color grading workflow.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Definiciones - 030 Shadows midtones highlights.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T020 CONCEPTOS\L010 DEFINICIONES\CAPITULOS EXPORTAR\010 Definiciones - 030 Shadows midtones highlights.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Definiciones - 040 Correccion primaria vs secundaria.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T020 CONCEPTOS\L010 DEFINICIONES\CAPITULOS EXPORTAR\010 Definiciones - 040 Correccion primaria vs secundaria.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Definiciones - 050 Lift Gamma Gain.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T020 CONCEPTOS\L010 DEFINICIONES\CAPITULOS EXPORTAR\010 Definiciones - 050 Lift Gamma Gain.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Definiciones - 060 Contrast.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T020 CONCEPTOS\L010 DEFINICIONES\CAPITULOS EXPORTAR\010 Definiciones - 060 Contrast.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Definiciones - 070 Hue.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T020 CONCEPTOS\L010 DEFINICIONES\CAPITULOS EXPORTAR\010 Definiciones - 070 Hue.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Definiciones - 080 Luma.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T020 CONCEPTOS\L010 DEFINICIONES\CAPITULOS EXPORTAR\010 Definiciones - 080 Luma.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Neutralizacion - 010 Balance de blancos automatico.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L010 NEUTRALIZACION\CAPITULOS EXPORTAR\010 Neutralizacion - 010 Balance de blancos automatico.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Neutralizacion - 020 Neutral grade 1.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L010 NEUTRALIZACION\CAPITULOS EXPORTAR\010 Neutralizacion - 020 Neutral grade 1.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Neutralizacion - 030 Neutral grade 2.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L010 NEUTRALIZACION\CAPITULOS EXPORTAR\010 Neutralizacion - 030 Neutral grade 2.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Neutralizacion - 040 Camera RAW 1.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L010 NEUTRALIZACION\CAPITULOS EXPORTAR\010 Neutralizacion - 040 Camera RAW 1.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Neutralizacion - 050 Camera RAW 2.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L010 NEUTRALIZACION\CAPITULOS EXPORTAR\020 Neutralizacion - 050 Camera RAW 2.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Neutralizacion - 060 Camera RAW 3.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L010 NEUTRALIZACION\CAPITULOS EXPORTAR\020 Neutralizacion - 060 Camera RAW 3.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Neutralizacion - 070 Camera RAW 4.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L010 NEUTRALIZACION\CAPITULOS EXPORTAR\020 Neutralizacion - 070 Camera RAW 4.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Neutralizacion - 080 Configurar footage de diferentes camaras 1.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L010 NEUTRALIZACION\CAPITULOS EXPORTAR\020 Neutralizacion - 080 Configurar footage de diferentes camaras 1.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Neutralizacion - 090 Configurar footage de diferentes camaras 2.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L010 NEUTRALIZACION\CAPITULOS EXPORTAR\020 Neutralizacion - 090 Configurar footage de diferentes camaras 2.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Color Matching - 010 Color Match.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L020 COLOR MATCHING\CAPITULOS EXPORTAR\020 Color Matching - 010 Color Match.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Color Matching - 020 Matching automatico.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L020 COLOR MATCHING\CAPITULOS EXPORTAR\020 Color Matching - 020 Matching automatico.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Color Matching - 030 Stills, Galeria, Matching y copia de grades 1.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L020 COLOR MATCHING\CAPITULOS EXPORTAR\020 Color Matching - 030 Stills, Galeria, Matching y copia de grades 1.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Color Matching - 040 Stills, Galeria, Matching y copia de grades 2.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L020 COLOR MATCHING\CAPITULOS EXPORTAR\020 Color Matching - 040 Stills, Galeria, Matching y copia de grades 2.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Color Matching - 050 Stills, Galeria, Matching y copia de grades 3.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L020 COLOR MATCHING\CAPITULOS EXPORTAR\020 Color Matching - 050 Stills, Galeria, Matching y copia de grades 3.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Color Matching - 060 Salvar y comparar versiones del grade.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L020 COLOR MATCHING\CAPITULOS EXPORTAR\020 Color Matching - 060 Salvar y comparar versiones del grade.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 030 Correccion Secundaria - 010 Que es la correccion secundaria.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L030 CORRECCION SECUNDARIA\CAPITULOS EXPORTAR\030 Correccion Secundaria - 010 Que es la correccion secundaria.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 030 Correccion Secundaria - 020 Uso naturalista de las mascaras 1.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L030 CORRECCION SECUNDARIA\CAPITULOS EXPORTAR\030 Correccion Secundaria - 020 Uso naturalista de las mascaras 1.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 030 Correccion Secundaria - 030 Uso naturalista de las mascaras 2.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L030 CORRECCION SECUNDARIA\CAPITULOS EXPORTAR\030 Correccion Secundaria - 030 Uso naturalista de las mascaras 2.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 030 Correccion Secundaria - 040 Mascaras para generar contraste por luz y oscuridad.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L030 CORRECCION SECUNDARIA\CAPITULOS EXPORTAR\030 Correccion Secundaria - 040 Mascaras para generar contraste por luz y oscuridad.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 030 Correccion Secundaria - 050 Mascaras personalizadas.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L030 CORRECCION SECUNDARIA\CAPITULOS EXPORTAR\030 Correccion Secundaria - 050 Mascaras personalizadas.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 030 Correccion Secundaria - 060 Añadir viñeteos a la imagen 1.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L030 CORRECCION SECUNDARIA\CAPITULOS EXPORTAR\030 Correccion Secundaria - 060 Añadir viñeteos a la imagen 1.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 030 Correccion Secundaria - 070 Añadir viñeteos a la imagen 2.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L030 CORRECCION SECUNDARIA\CAPITULOS EXPORTAR\030 Correccion Secundaria - 070 Añadir viñeteos a la imagen 2.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 030 Correccion Secundaria - 080 Uso de Qualifiers para conseguir contraste complementario.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L030 CORRECCION SECUNDARIA\CAPITULOS EXPORTAR\030 Correccion Secundaria - 080 Uso de Qualifiers para conseguir contraste complementario.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 030 Correccion Secundaria - 090 Utilizacion de texturas y mattes externos 1.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L030 CORRECCION SECUNDARIA\CAPITULOS EXPORTAR\030 Correccion Secundaria - 090 Utilizacion de texturas y mattes externos 1.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 030 Correccion Secundaria - 100 Utilizacion de texturas y mattes externos 2.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L030 CORRECCION SECUNDARIA\CAPITULOS EXPORTAR\030 Correccion Secundaria - 100 Utilizacion de texturas y mattes externos 2.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 040 LUTs - 010 Que es un LUT.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L040 LUTs\CAPITULOS EXPORTAR\040 LUTs - 010 Que es un LUT.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 040 LUTs - 020 Como usar un LUT.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L040 LUTs\CAPITULOS EXPORTAR\040 LUTs - 020 Como usar un LUT.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 040 LUTs - 030 Donde se coloca el LUT.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L040 LUTs\CAPITULOS EXPORTAR\040 LUTs - 030 Donde se coloca el LUT.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 040 LUTs - 040 Controlar la intensidad del LUT.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L040 LUTs\CAPITULOS EXPORTAR\040 LUTs - 040 Controlar la intensidad del LUT.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 040 LUTs - 050 Instalar LUTs.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L040 LUTs\CAPITULOS EXPORTAR\040 LUTs - 050 Instalar LUTs.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 040 LUTs - 060 Filmstock.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L040 LUTs\CAPITULOS EXPORTAR\040 LUTs - 060 Filmstock.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 050 Tecnicas de proyectos - 010 Grupos pre y post clip.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L050 TECNICAS DE PROYECTO\CAPITULOS EXPORTAR\050 Tecnicas de proyectos - 010 Grupos pre y post clip.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 050 Tecnicas de proyectos - 020 Tecnicas de organizacion para varias secuencias.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L050 TECNICAS DE PROYECTO\CAPITULOS EXPORTAR\050 Tecnicas de proyectos - 020 Tecnicas de organizacion para varias secuencias.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 050 Tecnicas de proyectos - 030 Remote grades.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L050 TECNICAS DE PROYECTO\CAPITULOS EXPORTAR\050 Tecnicas de proyectos - 030 Remote grades.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 050 Tecnicas de proyectos - 040 Davinci Resolve Looks.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T030 GRADING WORKFLOW\L050 TECNICAS DE PROYECTO\CAPITULOS EXPORTAR\050 Tecnicas de proyectos - 040 Davinci Resolve Looks.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Looks - 010 Que es un look.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T040 TECNICAS AVANZADAS\L010 LOOKS\CAPITULOS EXPORTAR\010 Looks - 010 Que es un look.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Looks - 020 Deconstruir un look.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T040 TECNICAS AVANZADAS\L010 LOOKS\CAPITULOS EXPORTAR\010 Looks - 020 Deconstruir un look.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Looks - 030 Color palettes.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T040 TECNICAS AVANZADAS\L010 LOOKS\CAPITULOS EXPORTAR\010 Looks - 030 Color palettes.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Looks - 040 Looks contextuales.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T040 TECNICAS AVANZADAS\L010 LOOKS\CAPITULOS EXPORTAR\010 Looks - 040 Looks contextuales.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Tonos de piel - 010 Corregir skintones.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T040 TECNICAS AVANZADAS\L020 TONOS DE PIEL\CAPITULOS EXPORTAR\020 Tonos de piel - 010 Corregir skintones.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Tonos de piel - 020 Ajustes generales.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T040 TECNICAS AVANZADAS\L020 TONOS DE PIEL\CAPITULOS EXPORTAR\020 Tonos de piel - 020 Ajustes generales.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Tonos de piel - 030 Desaturar diferentes rangos de color.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T040 TECNICAS AVANZADAS\L020 TONOS DE PIEL\CAPITULOS EXPORTAR\020 Tonos de piel - 030 Desaturar diferentes rangos de color.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Tonos de piel - 040 Recuperar tonos altos.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T040 TECNICAS AVANZADAS\L020 TONOS DE PIEL\CAPITULOS EXPORTAR\020 Tonos de piel - 040 Recuperar tonos altos.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Tonos de piel - 050 Aislar tonos altos.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T040 TECNICAS AVANZADAS\L020 TONOS DE PIEL\CAPITULOS EXPORTAR\020 Tonos de piel - 050 Aislar tonos altos.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Accion - 010 Introduccion.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Accion\CAPITULOS EXPORTAR\010 Look Accion - 010 Introduccion.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Accion - 020 Analisis del plano.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Accion\CAPITULOS EXPORTAR\010 Look Accion - 020 Analisis del plano.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Accion - 030 Configuracion del proyecto.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Accion\CAPITULOS EXPORTAR\010 Look Accion - 030 Configuracion del proyecto.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Accion - 040 Estrategias de grading.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Accion\CAPITULOS EXPORTAR\010 Look Accion - 040 Estrategias de grading.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Accion - 050 Grading 01.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Accion\CAPITULOS EXPORTAR\010 Look Accion - 050 Grading 01.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Accion - 060 Grading 02.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Accion\CAPITULOS EXPORTAR\010 Look Accion - 060 Grading 02.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Beauty - 010 Introduccion.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Beauty\CAPITULOS EXPORTAR\010 Beauty - 010 Introduccion.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Beauty - 020 Analisis del footage.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Beauty\CAPITULOS EXPORTAR\010 Beauty - 020 Analisis del footage.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Beauty - 030 Organizacion de los nodos.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Beauty\CAPITULOS EXPORTAR\010 Beauty - 030 Organizacion de los nodos.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Beauty - 040 Configuracion RAW.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Beauty\CAPITULOS EXPORTAR\010 Beauty - 040 Configuracion RAW.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Beauty - 050 Objetivo del etalonaje.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Beauty\CAPITULOS EXPORTAR\010 Beauty - 050 Objetivo del etalonaje.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Beauty - 060 Generar el look.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Beauty\CAPITULOS EXPORTAR\010 Beauty - 060 Generar el look.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Beauty - 070 Tecnicas de beauty.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Beauty\CAPITULOS EXPORTAR\010 Beauty - 070 Tecnicas de beauty.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Beauty - 080 Ajustes del pelo.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Beauty\CAPITULOS EXPORTAR\010 Beauty - 080 Ajustes del pelo.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Blanco y negro - 010 Crear el look.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Blanco y negro\CAPITULOS EXPORTAR\010 Look Blanco y negro - 010 Crear el look.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Bleach Bypass - 010 Balance de la imagen.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Bleach Bypass\CAPITULOS EXPORTAR\010 Look Bleach Bypass - 010 Balance de la imagen.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Bleach Bypass - 020 Metodo 1.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Bleach Bypass\CAPITULOS EXPORTAR\010 Look Bleach Bypass - 020 Metodo 1.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Bleach Bypass - 030 Metodo 2.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Bleach Bypass\CAPITULOS EXPORTAR\010 Look Bleach Bypass - 030 Metodo 2.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Bleach Bypass - 040 Metodo 3.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Bleach Bypass\CAPITULOS EXPORTAR\010 Look Bleach Bypass - 040 Metodo 3.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Bleach Bypass - 050 Anadir grano.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Bleach Bypass\CAPITULOS EXPORTAR\010 Look Bleach Bypass - 050 Anadir grano.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Cross Process - 010 Creacion del look.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Cross Process\CAPITULOS EXPORTAR\010 Look Cross Process - 010 Creacion del look.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Desaturar rangos de color - 010 Construir el look.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Desaturar rangos de color\CAPITULOS EXPORTAR\010 Look Desaturar rangos de color - 010 Construir el look.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Dia a noche - 010 Crear el look.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Dia a noche\CAPITULOS EXPORTAR\010 Look Dia a noche - 010 Crear el look.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Drama - 010 Introduccion.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Drama\CAPITULOS EXPORTAR\010 Look Drama - 010 Introduccion.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Drama - 020 Analisis del plano.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Drama\CAPITULOS EXPORTAR\010 Look Drama - 020 Analisis del plano.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Drama - 030 Estrategias de grading.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Drama\CAPITULOS EXPORTAR\010 Look Drama - 030 Estrategias de grading.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Drama - 040 Grading 01.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Drama\CAPITULOS EXPORTAR\010 Look Drama - 040 Grading 01.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Drama - 050 Grading 02.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Drama\CAPITULOS EXPORTAR\010 Look Drama - 050 Grading 02.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look High Key - 010 Creacion del look.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 High Key\CAPITULOS EXPORTAR\010 Look High Key - 010 Creacion del look.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Low Key - 010 Creacion del look.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Low Key\CAPITULOS EXPORTAR\010 Look Low Key - 010 Creacion del look.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Matching - 010 Setup del proyecto.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Matching\CAPITULOS EXPORTAR\010 Look Matching - 010 Setup del proyecto.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Matching - 020 Correccion primaria.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Matching\CAPITULOS EXPORTAR\010 Look Matching - 020 Correccion primaria.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Matching - 030 Correccion secundaria.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Matching\CAPITULOS EXPORTAR\010 Look Matching - 030 Correccion secundaria.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Matching - 040 Matching 01.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Matching\CAPITULOS EXPORTAR\010 Look Matching - 040 Matching 01.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Matching - 050 Matching 02.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Matching\CAPITULOS EXPORTAR\010 Look Matching - 050 Matching 02.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Music - 010 Introduccion.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Music\CAPITULOS EXPORTAR\010 Look Music - 010 Introduccion.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Music - 020 Analisis del plano.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Music\CAPITULOS EXPORTAR\010 Look Music - 020 Analisis del plano.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Music - 030 Configuracion del proyecto.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Music\CAPITULOS EXPORTAR\010 Look Music - 030 Configuracion del proyecto.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Music - 040 Estrategias de grading.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Music\CAPITULOS EXPORTAR\010 Look Music - 040 Estrategias de grading.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Music - 050 Grading 01.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Music\CAPITULOS EXPORTAR\010 Look Music - 050 Grading 01.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Music - 060 Grading 02.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Music\CAPITULOS EXPORTAR\010 Look Music - 060 Grading 02.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 ProductShot - 010 Introduccion.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Product Shot\CAPITULOS EXPORTAR\010 ProductShot - 010 Introduccion.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 ProductShot - 020 RAW y primeros pasos.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Product Shot\CAPITULOS EXPORTAR\010 ProductShot - 020 RAW y primeros pasos.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 ProductShot - 030 Grading.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Product Shot\CAPITULOS EXPORTAR\010 ProductShot - 030 Grading.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 ProductShot - 040 Repaso color wheels.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Product Shot\CAPITULOS EXPORTAR\010 ProductShot - 040 Repaso color wheels.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 ProductShot - 050 Toques finales.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Product Shot\CAPITULOS EXPORTAR\010 ProductShot - 050 Toques finales.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Terror - 010 Introduccion.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Terror\CAPITULOS EXPORTAR\010 Terror - 010 Introduccion.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Terror - 020 Analisis del plano.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Terror\CAPITULOS EXPORTAR\010 Terror - 020 Analisis del plano.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Terror - 030 Balance de la imagen.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Terror\CAPITULOS EXPORTAR\010 Terror - 030 Balance de la imagen.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Terror - 040 Grading 01.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Terror\CAPITULOS EXPORTAR\010 Terror - 040 Grading 01.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Terror - 050 Grading 02.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Terror\CAPITULOS EXPORTAR\010 Terror - 050 Grading 02.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Terror - 060 Grading 03.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Terror\CAPITULOS EXPORTAR\010 Terror - 060 Grading 03.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Vintage - 010 Introduccion.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Vintage\CAPITULOS EXPORTAR\010 Look Vintage - 010 Introduccion.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Vintage - 020 Analisis del plano.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Vintage\CAPITULOS EXPORTAR\010 Look Vintage - 020 Analisis del plano.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Vintage - 030 Configuracion del proyecto.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Vintage\CAPITULOS EXPORTAR\010 Look Vintage - 030 Configuracion del proyecto.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Vintage - 040 Node tree.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Vintage\CAPITULOS EXPORTAR\010 Look Vintage - 040 Node tree.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Vintage - 050 Estrategias de grading.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Vintage\CAPITULOS EXPORTAR\010 Look Vintage - 050 Estrategias de grading.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Vintage - 060 Grading 01.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Vintage\CAPITULOS EXPORTAR\010 Look Vintage - 060 Grading 01.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Vintage - 070 Grading 02.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Vintage\CAPITULOS EXPORTAR\010 Look Vintage - 070 Grading 02.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Vintage - 080 Grano.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Vintage\CAPITULOS EXPORTAR\010 Look Vintage - 080 Grano.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Vintage - 090 Light leak.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Vintage\CAPITULOS EXPORTAR\010 Look Vintage - 090 Light leak.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Look Vintage - 100 Correcciones de piel.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Vintage\CAPITULOS EXPORTAR\010 Look Vintage - 100 Correcciones de piel.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Wes Anderson - 010 Introduccion.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Wes Anderson\CAPITULOS EXPORTAR\010 Wes Anderson - 010 Introduccion.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Wes Anderson - 020 Configuracion del proyecto.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Wes Anderson\CAPITULOS EXPORTAR\010 Wes Anderson - 020 Configuracion del proyecto.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Wes Anderson - 030 Analisis del plano.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Wes Anderson\CAPITULOS EXPORTAR\010 Wes Anderson - 030 Analisis del plano.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Wes Anderson - 040 Grading 01.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Wes Anderson\CAPITULOS EXPORTAR\010 Wes Anderson - 040 Grading 01.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Wes Anderson - 050 Grading 02.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Wes Anderson\CAPITULOS EXPORTAR\010 Wes Anderson - 050 Grading 02.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Wes Anderson - 060 Grading 03.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\010 Wes Anderson\CAPITULOS EXPORTAR\010 Wes Anderson - 060 Grading 03.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Look Accion - 010 Introduccion.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Accion\CAPITULOS EXPORTAR\020 Look Accion - 010 Introduccion.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Look Accion - 020 Analisis del plano.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Accion\CAPITULOS EXPORTAR\020 Look Accion - 020 Analisis del plano.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Look Accion - 030 Estrategias de grading.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Accion\CAPITULOS EXPORTAR\020 Look Accion - 030 Estrategias de grading.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Look Accion - 040 Grading 01.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Accion\CAPITULOS EXPORTAR\020 Look Accion - 040 Grading 01.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Look Accion - 050 Grading 02.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Accion\CAPITULOS EXPORTAR\020 Look Accion - 050 Grading 02.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Look Accion - 060 Feedback cliente.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Accion\CAPITULOS EXPORTAR\020 Look Accion - 060 Feedback cliente.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Beauty - 010 Introduccion.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Beauty\CAPITULOS EXPORTAR\020 Beauty - 010 Introduccion.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Beauty - 020 Analisis de referencias.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Beauty\CAPITULOS EXPORTAR\020 Beauty - 020 Analisis de referencias.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Beauty - 030 Configuracion RAW.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Beauty\CAPITULOS EXPORTAR\020 Beauty - 030 Configuracion RAW.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Beauty - 040 Grading 01.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Beauty\CAPITULOS EXPORTAR\020 Beauty - 040 Grading 01.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Beauty - 050 Grading 02.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Beauty\CAPITULOS EXPORTAR\020 Beauty - 050 Grading 02.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Beauty - 060 Grading 03.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Beauty\CAPITULOS EXPORTAR\020 Beauty - 060 Grading 03.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Beauty - 070 Grading 04.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Beauty\CAPITULOS EXPORTAR\020 Beauty - 070 Grading 04.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Look Drama - 010 Introduccion.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Drama\CAPITULOS EXPORTAR\020 Look Drama - 010 Introduccion.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Look Drama - 020 Analisis del plano.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Drama\CAPITULOS EXPORTAR\020 Look Drama - 020 Analisis del plano.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Look Drama - 030 Configuracion del proyecto.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Drama\CAPITULOS EXPORTAR\020 Look Drama - 030 Configuracion del proyecto.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Look Drama - 040 Estrategias de grading.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Drama\CAPITULOS EXPORTAR\020 Look Drama - 040 Estrategias de grading.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Look Drama - 050 Grading 01.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Drama\CAPITULOS EXPORTAR\020 Look Drama - 050 Grading 01.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Look Drama - 060 Grading 02.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Drama\CAPITULOS EXPORTAR\020 Look Drama - 060 Grading 02.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Look Drama - 070 Grading 03.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Drama\CAPITULOS EXPORTAR\020 Look Drama - 070 Grading 03.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Look Music - 010 Introduccion.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Music\CAPITULOS EXPORTAR\020 Look Music - 010 Introduccion.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Look Music - 020 Analisis del plano.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Music\CAPITULOS EXPORTAR\020 Look Music - 020 Analisis del plano.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Look Music - 030 Estrategias de grading.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Music\CAPITULOS EXPORTAR\020 Look Music - 030 Estrategias de grading.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Look Music - 040 Grading 01.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Music\CAPITULOS EXPORTAR\020 Look Music - 040 Grading 01.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Look Music - 050 Grading 02.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Music\CAPITULOS EXPORTAR\020 Look Music - 050 Grading 02.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 ProductShot - 010 Introduccion.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Product Shot\CAPITULOS EXPORTAR\020 ProductShot - 010 Introduccion.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 ProductShot - 020 Uso de LUTs.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Product Shot\CAPITULOS EXPORTAR\020 ProductShot - 020 Uso de LUTs.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 ProductShot - 030 Grading 01.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Product Shot\CAPITULOS EXPORTAR\020 ProductShot - 030 Grading 01.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 ProductShot - 040 Grading 02.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Product Shot\CAPITULOS EXPORTAR\020 ProductShot - 040 Grading 02.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 ProductShot - 050 Grading 03.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Product Shot\CAPITULOS EXPORTAR\020 ProductShot - 050 Grading 03.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 ProductShot - 060 Denoise.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Product Shot\CAPITULOS EXPORTAR\020 ProductShot - 060 Denoise.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 ProductShot - 070 Regrain.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Product Shot\CAPITULOS EXPORTAR\020 ProductShot - 070 Regrain.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Terror - 010 Introduccion.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Terror\CAPITULOS EXPORTAR\020 Terror - 010 Introduccion.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Terror - 020 Configuracion del proyecto.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Terror\CAPITULOS EXPORTAR\020 Terror - 020 Configuracion del proyecto.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Terror - 030 Grading 01.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Terror\CAPITULOS EXPORTAR\020 Terror - 030 Grading 01.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Terror - 040 Grading 02.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Terror\CAPITULOS EXPORTAR\020 Terror - 040 Grading 02.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 020 Terror - 050 Ajustes finales.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\020 Terror\CAPITULOS EXPORTAR\020 Terror - 050 Ajustes finales.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 030 Look Drama - 010 Introduccion.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\030 Drama\CAPITULOS EXPORTAR\030 Look Drama - 010 Introduccion.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 030 Look Drama - 020 Configuracion del proyecto.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\030 Drama\CAPITULOS EXPORTAR\030 Look Drama - 020 Configuracion del proyecto.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 030 Look Drama - 030 Estrategias de grading.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\030 Drama\CAPITULOS EXPORTAR\030 Look Drama - 030 Estrategias de grading.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 030 Look Drama - 040 Grading 01.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\030 Drama\CAPITULOS EXPORTAR\030 Look Drama - 040 Grading 01.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 030 Look Drama - 050 Grading 02.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\030 Drama\CAPITULOS EXPORTAR\030 Look Drama - 050 Grading 02.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 030 Look Drama - 060 Feedback cliente.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T050 LOOKS\030 Drama\CAPITULOS EXPORTAR\030 Look Drama - 060 Feedback cliente.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Grading Suite - 010 Preparar el entorno.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T060 GRADING SUITE\L010 Grading Suite\CAPITULOS EXPORTAR\010 Grading Suite - 010 Preparar el entorno.mp4)
# [LOCATED FILE INFO ℹ️] Archivo localizado: 010 Grading Suite - 020 Monitores.mp4 (Ruta: \\animum.local\Produccion\LOL-Contenido\ASIGNATURAS\COLORISTA\T060 GRADING SUITE\L010 Grading Suite\CAPITULOS EXPORTAR\010 Grading Suite - 020 Monitores.mp4)
# ...
# [METADATA EXTRACTION PROGRESS] [===============     ] 76.42% completado (162/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 Look Music - 030 Estrategias de grading.mp4 | Duración: 00:10:51 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [===============     ] 76.89% completado (163/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 Look Music - 040 Grading 01.mp4 | Duración: 00:15:20 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [===============     ] 77.36% completado (164/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 Look Music - 050 Grading 02.mp4 | Duración: 00:10:58 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [===============     ] 77.83% completado (165/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 ProductShot - 010 Introduccion.mp4 | Duración: 00:05:46 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [===============     ] 78.30% completado (166/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 ProductShot - 020 Uso de LUTs.mp4 | Duración: 00:22:15 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [===============     ] 78.77% completado (167/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 ProductShot - 030 Grading 01.mp4 | Duración: 00:15:15 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [===============     ] 79.25% completado (168/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 ProductShot - 040 Grading 02.mp4 | Duración: 00:17:17 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [===============     ] 79.72% completado (169/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 ProductShot - 050 Grading 03.mp4 | Duración: 00:08:37 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [================    ] 80.19% completado (170/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 ProductShot - 060 Denoise.mp4 | Duración: 00:23:30 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [================    ] 80.66% completado (171/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 ProductShot - 070 Regrain.mp4 | Duración: 00:16:14 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [================    ] 81.13% completado (172/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 Terror - 010 Introduccion.mp4 | Duración: 00:03:27 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [================    ] 81.60% completado (173/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 Terror - 020 Configuracion del proyecto.mp4 | Duración: 00:09:33 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [================    ] 82.08% completado (174/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 Terror - 030 Grading 01.mp4 | Duración: 00:19:31 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [================    ] 82.55% completado (175/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 Terror - 040 Grading 02.mp4 | Duración: 00:10:59 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [================    ] 83.02% completado (176/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 Terror - 050 Ajustes finales.mp4 | Duración: 00:08:45 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [================    ] 83.49% completado (177/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 030 Look Drama - 010 Introduccion.mp4 | Duración: 00:01:49 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [================    ] 83.96% completado (178/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 030 Look Drama - 020 Configuracion del proyecto.mp4 | Duración: 00:02:37 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [================    ] 84.43% completado (179/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 030 Look Drama - 030 Estrategias de grading.mp4 | Duración: 00:06:20 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [================    ] 84.91% completado (180/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 030 Look Drama - 040 Grading 01.mp4 | Duración: 00:13:15 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [=================   ] 85.38% completado (181/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 030 Look Drama - 050 Grading 02.mp4 | Duración: 00:08:01 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [=================   ] 85.85% completado (182/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 030 Look Drama - 060 Feedback cliente.mp4 | Duración: 00:13:40 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [=================   ] 86.32% completado (183/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 010 Grading Suite - 010 Preparar el entorno.mp4 | Duración: 00:04:28 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [=================   ] 86.79% completado (184/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 010 Grading Suite - 020 Monitores.mp4 | Duración: 00:07:56 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [=================   ] 87.26% completado (185/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 010 Pipeline - 010 Pipeline de color grading.mp4 | Duración: 00:14:55 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [=================   ] 87.74% completado (186/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 010 Color Management - 010 Introduccion a la gestion de espacios de color.mp4 | Duración: 00:08:11 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [=================   ] 88.21% completado (187/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 010 Color Management - 020 Sistemas de color.mp4 | Duración: 00:15:10 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [=================   ] 88.68% completado (188/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 010 Color Management - 030 Gamut.mp4 | Duración: 00:05:37 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [=================   ] 89.15% completado (189/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 010 Color Management - 040 Rango dinamico.mp4 | Duración: 00:05:08 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [=================   ] 89.62% completado (190/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 010 Color Management - 050 Curva tonal.mp4 | Duración: 00:15:33 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [==================  ] 90.09% completado (191/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 010 Color Management - 060 Standards.mp4 | Duración: 00:07:08 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [==================  ] 90.57% completado (192/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 010 Color Management - 070 Workflow.mp4 | Duración: 00:10:38 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [==================  ] 91.04% completado (193/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 010 Color Management - 080 VFX.mp4 | Duración: 00:13:11 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [==================  ] 91.51% completado (194/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 010 Color Management - 090 RAW.mp4 | Duración: 00:03:26 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [==================  ] 91.98% completado (195/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 010 Color Management - 100 ACES.mp4 | Duración: 00:16:29 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [==================  ] 92.45% completado (196/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 010 Color Management - 110 HDR.mp4 | Duración: 00:14:47 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [==================  ] 92.92% completado (197/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 010 Color Management - 120 Metadata HDR.mp4 | Duración: 00:06:18 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [==================  ] 93.40% completado (198/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 Gestion Color Management - 010 Intro.mp4 | Duración: 00:04:58 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [==================  ] 93.87% completado (199/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 Gestion Color Management - 020 Esquema simple.mp4 | Duración: 00:05:04 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [==================  ] 94.34% completado (200/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 Gestion Color Management - 030 Color Space manual vs color managed.mp4 | Duración: 00:06:03 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [==================  ] 94.81% completado (201/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 Gestion Color Management - 040 Customizacion de Color Space.mp4 | Duración: 00:05:36 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [=================== ] 95.28% completado (202/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 Gestion Color Management - 050 DaVinci Wide Gamut.mp4 | Duración: 00:07:05 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [=================== ] 95.75% completado (203/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 Gestion Color Management - 060 CM en el arbol nodal.mp4 | Duración: 00:08:09 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [=================== ] 96.23% completado (204/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 Gestion Color Management - 070 ACES Project.mp4 | Duración: 00:08:04 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [=================== ] 96.70% completado (205/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 Gestion Color Management - 080 ACES node tree.mp4 | Duración: 00:03:21 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [=================== ] 97.17% completado (206/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 Gestion Color Management - 090 Color Space desconocido.mp4 | Duración: 00:09:27 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [=================== ] 97.64% completado (207/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 Gestion Color Management - 100 Flujos de trabajo con gestion cromatica I.mp4 | Duración: 00:16:36 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [=================== ] 98.11% completado (208/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 Gestion Color Management - 100 Flujos de trabajo con gestion cromatica II.mp4 | Duración: 00:07:24 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [=================== ] 98.58% completado (209/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 Gestion Color Management - 100 Flujos de trabajo con gestion cromatica III.mp4 | Duración: 00:07:27 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [=================== ] 99.06% completado (210/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 Gestion Color Management - 100 Flujos de trabajo con gestion cromatica Introduccion.mp4 | Duración: 00:05:23 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [=================== ] 99.53% completado (211/212)
# [METADATA EXTRACTION INFO ℹ️] Procesado: 020 Gestion Color Management - 110 LUT vs Gestion cromatica.mp4 | Duración: 00:18:38 | Resolución: 1920x1080
# [METADATA EXTRACTION PROGRESS] [====================] 100.00% completado (212/212)
# [METADATA EXTRACTION SUCCESS ✅] Extracción de metadatos completada.
# [BACKUP INFO ℹ️] Datos respaldados localmente en: video_files_backup.csv
# [PROCESS METRICS INFO ℹ️] Total de videos procesados: 212 | Duración: 29.20 segundos
# [PROCESS END [FINISHED ✅]] Proceso completado exitosamente.
#                                              file_name  \
# 0    010 Como funciona el curso - 010 Como funciona...
# 1       010 Teoria del color - 010 Que es el color.mp4
# 2      010 Teoria del color - 020 El color tecnico.mp4
# 3    010 Teoria del color - 030 Percepcion del colo...
# 4    010 Teoria del color - 040 Colores primarios y...
# ..                                                 ...
# 207  020 Gestion Color Management - 100 Flujos de t...
# 208  020 Gestion Color Management - 100 Flujos de t...
# 209  020 Gestion Color Management - 100 Flujos de t...
# 210  020 Gestion Color Management - 100 Flujos de t...
# 211  020 Gestion Color Management - 110 LUT vs Gest...
#
#                                              file_path  \
# 0    \\animum.local\Produccion\LOL-Contenido\ASIGNA...
# 1    \\animum.local\Produccion\LOL-Contenido\ASIGNA...
# 2    \\animum.local\Produccion\LOL-Contenido\ASIGNA...
# 3    \\animum.local\Produccion\LOL-Contenido\ASIGNA...
# 4    \\animum.local\Produccion\LOL-Contenido\ASIGNA...
# ..                                                 ...
# 207  \\animum.local\Produccion\LOL-Contenido\ASIGNA...
# 208  \\animum.local\Produccion\LOL-Contenido\ASIGNA...
# 209  \\animum.local\Produccion\LOL-Contenido\ASIGNA...
# 210  \\animum.local\Produccion\LOL-Contenido\ASIGNA...
# 211  \\animum.local\Produccion\LOL-Contenido\ASIGNA...
#
#             file_creation_date    file_last_modified_date  \
# 0   2021-02-09 08:52:29.217577 2021-02-09 08:52:34.048862
# 1   2021-02-23 10:47:38.413409 2021-02-23 10:47:39.390923
# 2   2021-02-23 10:48:28.215291 2021-02-23 10:48:28.315301
# 3   2021-02-23 10:49:46.757849 2021-02-23 10:49:47.756120
# 4   2021-02-23 10:52:13.366395 2021-02-23 10:52:14.819046
# ..                         ...                        ...
# 207 2024-09-24 11:46:32.062783 2024-09-24 11:46:38.420203
# 208 2024-09-24 11:48:34.229124 2024-09-24 11:48:37.074637
# 209 2024-09-24 11:50:36.078466 2024-09-24 11:50:38.667874
# 210 2024-09-24 11:42:14.313174 2024-09-24 11:42:16.176010
# 211 2024-09-24 11:40:45.591653 2024-09-24 11:40:52.008157
#
#                file_scrap_date  file_size_mb duration_hms  duration_ms  \
# 0   2025-06-12 15:35:58.934822           208     00:15:28       928200
# 1   2025-06-12 15:35:59.048482            23     00:01:31        91600
# 2   2025-06-12 15:35:59.152619             3     00:01:05        65840
# 3   2025-06-12 15:35:59.265183            24     00:02:49       169920
# 4   2025-06-12 15:35:59.385727            62     00:04:30       270720
# ..                         ...           ...          ...          ...
# 207 2025-06-12 15:36:24.998454           252     00:16:36       996320
# 208 2025-06-12 15:36:25.112627           112     00:07:24       444960
# 209 2025-06-12 15:36:25.238969           113     00:07:27       447120
# 210 2025-06-12 15:36:25.347139            82     00:05:23       323000
# 211 2025-06-12 15:36:25.463074           283     00:18:38      1118120
#
#     video_codec  video_bitrate_kbps  video_fps video_resolution audio_codec  \
# 0          h264                1561       25.0        1920x1080         aac
# 1          h264                2017       25.0        1920x1080         aac
# 2          h264                 300       25.0        1920x1080         aac
# 3          h264                1059       25.0        1920x1080         aac
# 4          h264                1793       25.0        1920x1080         aac
# ..          ...                 ...        ...              ...         ...
# 207        h264                1999       25.0        1920x1080         aac
# 208        h264                1999       25.0        1920x1080         aac
# 209        h264                2000       25.0        1920x1080         aac
# 210        h264                2003       25.0        1920x1080         aac
# 211        h264                2000       25.0        1920x1080         aac
#
#      audio_bitrate_kbps  audio_channels  audio_sample_rate_hz
# 0                   317               2                 48000
# 1                   125               1                 48000
# 2                   125               1                 48000
# 3                   125               1                 48000
# 4                   125               1                 48000
# ..                  ...             ...                   ...
# 207                 125               1                 44100
# 208                 125               1                 44100
# 209                 125               1                 44100
# 210                 125               1                 44100
# 211                 125               1                 44100
#
# [212 rows x 16 columns]

# %%
from dpm_utils_functions.dpm_tables import table_various_sources_to_DF
from dpm_common_functions import _ini_authenticate_API

# Configuración
params_dic = {
    "spreadsheet_source_table_id": "docs.google.com/spreadsheets/d/1SzrRm8nUPPZqU_LE-xdDNdB7rLUdePkjgV4IuPA2U3o",
    "spreadsheet_source_table_worksheet_name": "ARCHIVOS LIST",

    "ini_environment_identificated": ini_environment_identificated,
    "json_keyfile_local": GCP_json_keyfile_local,
    "json_keyfile_colab": GCP_json_keyfile_colab,
    "json_keyfile_GCP_secret_id": GCP_json_keyfile_GCP_secret_id,
}



df_original = table_various_sources_to_DF(params_dic)
df_original.info()
# Out:
# [EXTRACTION [START ⏳]] Extrayendo datos de Google Sheets...
# [EXTRACTION [SUCCESS ✅]] Datos extraídos con éxito de la hoja 'ARCHIVOS LIST'.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6067 entries, 0 to 6066
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   file_name                6067 non-null   object
#  1   file_path                6067 non-null   object
#  2   file_creation_date       6067 non-null   object
#  3   file_last_modified_date  6067 non-null   object
#  4   file_scrap_date          6067 non-null   object
#  5   file_size_mb             6067 non-null   object
#  6   duration_hms             6067 non-null   object
#  7   duration_ms              6067 non-null   object
#  8   video_codec              6067 non-null   object
#  9   video_bitrate_kbps       6067 non-null   object
#  10  video_fps                6067 non-null   object
#  11  video_resolution         6067 non-null   object
#  12  audio_codec              6067 non-null   object
#  13  audio_bitrate_kbps       6067 non-null   object
#  14  audio_channels           6067 non-null   object
#  15  audio_sample_rate_hz     6067 non-null   object
# dtypes: object(16)
# memory usage: 758.5+ KB

# %%
config = {
    "reference_dtype_df": df_videos,   # DataFrame con los dtypes de referencia
    "target_dtype_df": df_original    # DataFrame al que se le aplicarán esos dtypes
}
from dpm_utils_functions.dpm_tables import DType_df_to_df
df_original_casted, meta = DType_df_to_df(config)
# Out:
# 🔹🔹🔹 [START ▶️] DTYPE COPY
# [DTYPE COPY ℹ️] (1/16) 'file_name' ya es object. Skipped.
# [DTYPE COPY ℹ️] (2/16) 'file_path' ya es object. Skipped.
# [DTYPE COPY ✅] (3/16) 'file_creation_date' → datetime64[ns].
# [DTYPE COPY ✅] (4/16) 'file_last_modified_date' → datetime64[ns].
# [DTYPE COPY ✅] (5/16) 'file_scrap_date' → datetime64[ns].
# [DTYPE COPY ✅] (6/16) 'file_size_mb' → int64.
# [DTYPE COPY ℹ️] (7/16) 'duration_hms' ya es object. Skipped.
# [DTYPE COPY ✅] (8/16) 'duration_ms' → Int64.
# [DTYPE COPY ℹ️] (9/16) 'video_codec' ya es object. Skipped.
# [DTYPE COPY ✅] (10/16) 'video_bitrate_kbps' → int64.
# [DTYPE COPY ✅] (11/16) 'video_fps' → float64.
# [DTYPE COPY ℹ️] (12/16) 'video_resolution' ya es object. Skipped.
# [DTYPE COPY ℹ️] (13/16) 'audio_codec' ya es object. Skipped.
# [DTYPE COPY ✅] (14/16) 'audio_bitrate_kbps' → int64.
# [DTYPE COPY ✅] (15/16) 'audio_channels' → int64.
# [DTYPE COPY ✅] (16/16) 'audio_sample_rate_hz' → int64.
# [DTYPE COPY ✔️] Cast fin — ok: 10/16 | fail: 0 | skipped: 6
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6067 entries, 0 to 6066
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   file_name                6067 non-null   object
#  1   file_path                6067 non-null   object
#  2   file_creation_date       6067 non-null   datetime64[ns]
#  3   file_last_modified_date  6067 non-null   datetime64[ns]
#  4   file_scrap_date          6067 non-null   datetime64[ns]
#  5   file_size_mb             6067 non-null   int64
#  6   duration_hms             6067 non-null   object
#  7   duration_ms              6066 non-null   Int64
#  8   video_codec              6067 non-null   object
#  9   video_bitrate_kbps       6067 non-null   int64
#  10  video_fps                6067 non-null   float64
#  11  video_resolution         6067 non-null   object
#  12  audio_codec              6067 non-null   object
#  13  audio_bitrate_kbps       6067 non-null   int64
#  14  audio_channels           6067 non-null   int64
#  15  audio_sample_rate_hz     6067 non-null   int64
# dtypes: Int64(1), datetime64[ns](3), float64(1), int64(5), object(6)
# memory usage: 764.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212 entries, 0 to 211
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   file_name                212 non-null    object
#  1   file_path                212 non-null    object
#  2   file_creation_date       212 non-null    datetime64[ns]
#  3   file_last_modified_date  212 non-null    datetime64[ns]
#  4   file_scrap_date          212 non-null    datetime64[ns]
#  5   file_size_mb             212 non-null    int64
#  6   duration_hms             212 non-null    object
#  7   duration_ms              212 non-null    int64
#  8   video_codec              212 non-null    object
#  9   video_bitrate_kbps       212 non-null    int64
#  10  video_fps                212 non-null    float64
#  11  video_resolution         212 non-null    object
#  12  audio_codec              212 non-null    object
#  13  audio_bitrate_kbps       212 non-null    int64
#  14  audio_channels           212 non-null    int64
#  15  audio_sample_rate_hz     212 non-null    int64
# dtypes: datetime64[ns](3), float64(1), int64(6), object(6)
# memory usage: 26.6+ KB

# %%
# 1️⃣ Configuración

config = {
    "validate_df_schemas_match" : True, # valida esquema primero

    "df_initial"   : df_original_casted,
    "df_to_merge"  : df_videos,
    "id_fields"    : ["file_name", "duration_ms"],

    "duplicate_policy": "keep_newest",   # keep_newest | keep_oldest | keep_df_initial | keep_df_to_merge
    "duplicate_date_field"       : "file_scrap_date",
    "duplicate_date_field_format_str"  : "%d/%m/%Y",


    "return_metadata"  : True
}


# Llamada a la función
from dpm_utils_functions.dpm_tables import tables_consolidate_duplicates_df
result_df, metadata = tables_consolidate_duplicates_df(config)
# Out:
# [CONSOLIDATION START ▶️] 2025-06-12T15:46:46
# INFO ℹ️ id_fields=['file_name', 'duration_ms'] | policy=keep_newest
# FINISHED ✅ registros finales=6064 | duplicados_resueltos=215

# %%
# @title SUBIDA A GOOGLE SHEETS
config = {
    "df": result_df,
    'spreadsheet_target_table_id': 'https://docs.google.com/spreadsheets/d/1SzrRm8nUPPZqU_LE-xdDNdB7rLUdePkjgV4IuPA2U3o',
    # Nombre de la pestaña (worksheet) destino
    'spreadsheet_target_table_worksheet_name': 'ResponseAPI',

    "ini_environment_identificated": ini_environment_identificated,
    "json_keyfile_local": GCP_json_keyfile_local,
    "json_keyfile_colab": GCP_json_keyfile_colab,
    "json_keyfile_GCP_secret_id": GCP_json_keyfile_GCP_secret_id,
}
from dpm_utils_functions.dpm_tables import table_DF_to_various_targets

table_DF_to_various_targets(config)
# Out:
# 🔹🔹🔹 [START ▶️] Iniciando escritura de DataFrame en destino configurado 🔹🔹🔹
#
# [METRICS [INFO ℹ️]] DataFrame recibido: 6064 filas × 16 columnas.
#
# [LOAD [START ▶️]] Iniciando escritura en Google Sheets…
# [LOAD [SUCCESS ✅]] Se actualizaron N/A celdas en Google Sheets.
# [METRICS [INFO ℹ️]] Destino final: https://docs.google.com/spreadsheets/d/1SzrRm8nUPPZqU_LE-xdDNdB7rLUdePkjgV4IuPA2U3o
#
# 🔹🔹🔹 [END [FINISHED ✅]] Escritura completada exitosamente. 🔹🔹🔹
